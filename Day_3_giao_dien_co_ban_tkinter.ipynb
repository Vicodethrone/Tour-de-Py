# %% [markdown]
# <a href="https://colab.research.google.com/github/Vicodethrone/Tour-de-Py/blob/main/Day_3_giao_dien_co_ban_tkinter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TKINTER
# Tkinter là thư viện GUI tiêu chuẩn cho Python. Khi kết hợp với Tkinter, Python sẽ được cung cấp các công cụ một cách nhanh chóng và dễ dàng để tạo các ứng dụng GUI. Tkinter cung cấp giao diện hướng đối tượng mạnh mẽ đến các bộ công cụ Tk GUI.
# Để tạo một ứng dụng sử dụng tkinter thì sau đây là những việc cần làm:
#
# - Nhập mô đun Tkinter
#
# - Tạo cửa sổ ứng dụng chính của GUI
#
# - Thêm một vài widgets vào ứng dụng GUI
#
# - Nhập vòng lặp event chính để thực hiện hành động với từng sự kiện do người dùng kích hoạt

# %% [markdown]
# Đoạn code sau đây ví dụ cách tạo cửa sổ bằng Tkinter

# %%
from tkinter import Tk, Frame #từ module tkinter ta import hai lớp Tk(tạo cửa sổ), Frame(quản lý widget)
 
class Example(Frame):
  def __init__(self, parent):
    Frame.__init__(self, parent, background="white")
"""Định nghĩa lớp Example kế thừa từ lớp Frame. Lớp Frame là một widget 
dùng để quản lý các widet khác – các lớp kiểu này được gọi chung là containter 
hoặc layout. Trong phương thức khởi tạo __init__() chúng ta gọi lại phương thức 
khởi tạo từ lớp Frame và đưa vào tham số màu nền."""
  self.parent = parent
# dùng thuộc tính parent để lưu lại đối tượng root.
  self.initUI()
# định nghĩa phương thức initUI() dùng để tạo các widget trên cửa sổ.

def initUI(self):
 self.parent.title("Simple")
# Phương thức title() sẽ thay đổi tiêu đề cửa sổ.
 self.pack(fill=BOTH, expand=1)
 """Phương thức pack() có tác dụng sắp xếp vị trí các widget trước khi gắn 
 chúng lên cửa sổ chính. Tham số fill=BOTH sẽ dãn widget ra theo chiều ngang 
 và chiều rộng, tức là widget đó sẽ chiếm toàn bộ không gian cửa sổ."""
  
root = Tk()
"""Ở dòng trên chúng ta tạo một cửa sổ và gán vào biến root để quản lý. 
Cửa sổ luôn phải được tạo trước khi tạo các widget """
root.geometry("250x150+300+300")
"""Phương thức geometry() quy định kích thước cửa sổ và vị trí hiển thị trên 
màn hình. Hai tham số đầu tiên là kích thước cửa sổ, hai phương thức sau là vị 
trí của cửa sổ trên màn hình. """
app = Example(root)
# tạo một Frame và gắn nó vào cửa sổ chính
root.mainloop()
# mainloop () phương thức giúp cửa sổ mới hiện lên màn hình và bắt đầu nhận các sự kiện để xử lý.

# %% [markdown]
# ![Capture-41.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Quản lý layout
# Trong Tkinter có 3 loại layout là pack, grid và place. Trong đó place là kiểu layout tự do, thuật ngữ gọi là Absolute Positioning, tức là bạn sẽ phải tự quy định vị trí cũng như kích thước của các widget. Layout pack sắp xếp các widget của bạn theo chiều ngang và chiều dọc. Còn layout grid sắp xếp widget theo dạng bảng.

# %% [markdown]
# ## Thiết kế tự do
# Khi thiết kế theo kiểu tự do này chúng ta sẽ phải tự quy định vị trí và kích thước cho các widget trên màn hình, nếu kích thước cửa sổ thay đổi thì kích thước và vị trí của các widget không thay đổi. Thiết kế theo kiểu tự do cũng rất bất tiện khi bạn muốn thay đổi, thêm hay bớt các widget thì hầu như bạn sẽ phải sắp xếp lại toàn bộ widget nên thường sẽ thiết kế theo layout.

# %%
# tạo file absolute.py hiển thị 3 hình ảnh trên cửa sổ
from PIL import Image, ImageTk
"""Để hiển thị ảnh thì chúng ta có thể dùng module PhotoImage trong gói Tkinter 
nhưng module này rất hạn chế nên ở đây mình dùng module Image và ImageTk trong 
thư viện Pillow """
from tkinter import Tk, Label, BOTH
from tkinter.ttk import Frame, Style
 
class Example(Frame):
   def __init__(self, parent):
     Frame.__init__(self, parent)
  
     self.parent = parent
     self.initUI()
  
   def initUI(self):
     self.parent.title("Absolute positioning")
     self.pack(fill=BOTH, expand=1)
  
     Style().configure("TFrame", background="#333") #tô màu nền cửa sổ là màu xám đen
  
     bard = Image.open("C:\\bardejov.jpg")
     bardejov = ImageTk.PhotoImage(bard)
     # Hai dòng trên sẽ tạo các đối tượng ảnh và tải chúng vào chương trình.
     label1 = Label(self, image=bardejov)
     # Tạo đối tượng Label, đây là một lớp dùng để hiển thị chữ và ảnh.
     label1.image = bardejov
     # Lưu lại tham chiếu đến ảnh nếu không sẽ bị xóa.
     label1.place(x=20, y=20)
     # Đặt ảnh tại vị trí x = 20 và y = 20.
   
     rot = Image.open("C:\\rotunda.jpg")
     rotunda = ImageTk.PhotoImage(rot)
     label2 = Label(self, image=rotunda)
     label2.image = rotunda
     label2.place(x=40, y=160)
  
     minc = Image.open("C:\\mincol.jpg")
     mincol = ImageTk.PhotoImage(minc)
     label3 = Label(self, image=mincol)
     label3.image = mincol
     label3.place(x=170, y=50)
  
root = Tk()
root.geometry("300x280+300+300")
app = Example(root)
root.mainloop()

# %% [markdown]
# ![Capture-43.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Grid layout
# Grid layout là giao diện đặt các widget con trong một bảng 2 chiều. Widget chính được chia thành một số hàng và cột và mỗi “ô” trong bảng kết quả có thể chứa một widget con. Đây là trình quản lý hình họat linh hoạt nhất trong Tkinter.
#
# Nguồn: [geeksforgeeks](https://www.geeksforgeeks.org/python-grid-method-in-tkinter/)
#
# Để tìm hiểu rõ hơn về phương thức grid các bãn hãy tham khảo [plus2net.com](https://www.plus2net.com/python/tkinter-grid.php)

# %% [markdown]
# ![download8.png](data:image/png;base64,...)

# %%
# import tkinter module
from tkinter import * from tkinter.ttk import *

# creating main tkinter window/toplevel
master = Tk()

# this wil create a label widget
l1 = Label(master, text = "First:")
l2 = Label(master, text = "Second:")

# grid method to arrange labels in respective
# rows and columns as specified
l1.grid(row = 0, column = 0, sticky = W, pady = 2)
l2.grid(row = 1, column = 0, sticky = W, pady = 2)

# entry widgets, used to take entry from user
e1 = Entry(master)
e2 = Entry(master)

# this will arrange entry widgets
e1.grid(row = 0, column = 1, pady = 2)
e2.grid(row = 1, column = 1, pady = 2)

# infinite loop which can be terminated by keyboard
# or mouse interrupt
mainloop()

# %% [markdown]
# ![Capture34-3.png](data:image/png;base64,...)

# %% [markdown]
# # CÁC WIDGET CƠ BẢN
# Widget là các thành phần cấu tạo nên một ứng dụng GUI. Widget rất đa dạng, có một số widget quan trọng cần phải có của bất kì nền tảng nào kể cả Tkinter ví dụ như button (nút bấm), check box hay scroll bar (thanh cuộn). Ngoài những widget cơ bản lập trình viên còn có thể tùy chỉnh widget của riêng mình.

# %% [markdown]
# ## Button
# đây là widget hiển thị nút trong ứng dụng

# %%
#Syntax
Button (master, option = value)
# master: để khai báo root hoặc parent window
# option: định hình button với các thuộc tính activebackground color, 
#activeforeground color, bg, font, image, width, height, command, etc

# %%
#Example
import tkinter as tk
r = tk.Tk()
button = tk.Button(r, text='click me', width=25, command=r.destroy)
button.pack()
r.mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Check button
# Sử dụng để hiển thị một số tùy chọn dưới dạng hộp kiểm và có thể chọn nhiều tùy chọn cùng một lúc.

# %%
#Syntax
CheckButton (master, option = value)
""""option ở đây có thể là title to the widget, activebackground, và 
activeforeground để set back và foreground color, bg để set background color, 
command, font, image, etc"""

# %%
#Example
from tkinter import *
root = Tk()
v1 = IntVar()
Checkbutton(root, text='Python',width =25, variable=v1).grid(row=0, sticky=S)
v2 = IntVar()
Checkbutton(root, text='Unix',width =25, variable=v2).grid(row=1, sticky=S)
v3 = IntVar()
Checkbutton(root, text='Perl',width =25, variable=v3).grid(row=2, sticky=S)
mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Radio button
#
# Sử dụng để hiển thị một số tùy chọn dưới dạng các nút radio. Người dùng chỉ có thể chọn một tùy chọn tại một thời điểm.

# %%
#Syntax
RadioButton (master, option = values)

# %%
#Example
from tkinter import *
root = Tk()
v = IntVar()
Radiobutton(root, text='male',width =25, variable=v, value=1).pack(anchor=W)
Radiobutton(root, text='female',width =25, variable=v, value=2).pack(anchor=W)
Radiobutton(root, text='others',width =25, variable=v, value=3).pack(anchor=W)
mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Menu button
#
# sử dụng để hiển thị các menu trong ứng dụng bằng cách liên kết với widget menu và show các option khi click vào

# %%
#Syntax
MenuButton (master, option = value)

# %%
#Example
from tkinter import *
root = Tk()
root.geometry("300x350")
menubutton = Menubutton(root, text = "File", width = 35)
menubutton.grid()
menubutton.menu = Menu(menubutton)
menubutton["menu"]=menubutton.menu
menubutton.menu.add_checkbutton(label = "New file", variable=IntVar())
menubutton.menu.add_checkbutton(label = "Save", variable = IntVar())
menubutton.menu.add_checkbutton(label = "Save as", variable = IntVar())
menubutton.pack()
root.mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## List box
# Sử dụng để cung cấp danh sách các tùy chọn cho người dùng.

# %%
#Syntax
w = Listbox(master, option,..)
# những option widget phổ biến của listbox 
# https://www.educba.com/tkinter-listbox/

# %%
#Example
from tkinter import *
import tkinter
top1 = Tk()
lb = Listbox(top1)
lb.insert(1, "Bangalore")
lb.insert(2, "Mysore")
lb.insert(3, "Mangalore")
lb.insert(4, "Hubli")
lb.insert(5, "Dharwad")
lb.insert(6, "Belgaum")
lb.pack()
top1.mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entry
# Sử dụng để hiển thị trường văn bản một dòng để chấp nhận các giá trị từ người dùng.

# %%
#Syntax
Entry (master, option = value)
"""option có thể là  bd để set border, bg cho background color, command, height, 
width,..."""

# %%
#Example
from tkinter import *
root = Tk()
root.geometry("300x350")
Label(root, text='Enter the College Name').grid(row=0)
Label(root, text='Enter the Course name').grid(row=1)
e1 = Entry(root)
e2 = Entry(root)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Label
# Sử dụng để cung cấp chú thích một dòng cho các tiện ích con khác. Nó cũng có thể chứa hình ảnh.

# %%
#Syntax
Label (master, option = value)
#option giống Entry

# %%
from tkinter import *
root = Tk()
root.geometry("300x350")
r = Label(root, text='Educba Training',width =35)
r.pack()
root.mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Tham khảo
#
# [geeksforgeeks](https://www.geeksforgeeks.org/python-tkinter-tutorial/#basic)
#
# [pythonbasics.org](https://pythonbasics.org/tkinter/)
#
# [tutorialspoint.com](https://www.tutorialspoint.com/python/python_gui_programming.htm)
#
# [educba.com](https://www.educba.com/python-tkinter/?source=leftnav)
#
# [phocode.com](https://phocode.com/python/python-tkinter-lap-trinh-gui-voi-tkinter/)
