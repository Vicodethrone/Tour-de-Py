# %% [markdown]
# <a href="https://colab.research.google.com/github/Vicodethrone/Tour-de-Py/blob/main/Day_10_Tic_tac_toe_nh%E1%BA%ADp_t%E1%BB%AB_b%C3%A0n_ph%C3%ADm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tic-Tac-Toe
# Hay còn được gọi là cờ caro, là một trò chơi cổ điển đơn giản rất phổ biến ở giới học sinh vớ.
#
# Ở phần này chúng ta sẽ tìm hiểu về luật chơi, giải thuật được sử dụng để tận dụng ý tưởng luật chơi và cuối cùng là giải thích code

# %% [markdown]
# # Phần 1: Luật chơi
# ## 1. Giới thiệu
#
# Đây là trò chơi hai người, người đi trước sẽ điền "X" và người còn lại sẽ điền "O" chơi ở một bảng 3x3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Luật chơi:
# * Người đầu tiên sẽ điền "X" vào một trong các ô trống có sẵn.
# * Người tiếp theo sẽ điền "O" vào ô trống khác với các ô đã được điền.
# * Mục tiêu của người chơi là đặt các dấu hiệu tương ứng của họ hoàn toàn theo hàng hoặc theo cột, hoặc theo đường chéo.
# * Trò chơi tiếp tục cho đến khi một người chơi thắng trò chơi hoặc kết thúc trò chơi hòa bằng cách điền vào tất cả các ô mà không có trận thắng.
#
# ![image.png](data:image/png;base64,...)
#
# Người chơi "X" đã hoàn thành đường chéo nên đã thắng trò chơi

# %% [markdown]
# ## 3. Cách cách thắng trò chơi (8 cách)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Và cuối cùng là kết quả hoà khi mà tất cả các ô được điền mà không có đường thẳng, đường chéo, hay đường ngang của "X" hoặc "O"
#
# Để hiểu rõ hơn về trò chơi bạn có thể vào [đây](https://www.google.com/search?q=tic+tac+toe&rlz=1C1ONGR_enIN963IN963&oq=tic+tac+toe&aqs=chrome..69i57j35i39j0i67l4j69i60l2.3997j0j1&sourceid=chrome&ie=UTF-8)

# %% [markdown]
# # Phần 2: Giải thuật
# 1. Tạo bảng bằng mảng 2 chiều và khởi tạo mỗi phần tử dưới dạng trống(để thể hiện sự rỗng có thể sử dụng "-" ).
# 2. Viết hàm để check xem bảng được điền chưa (dùng vòng lặp và câu lệnh điều kiện để kiểm tra nếu bảng trống thì false ngược lại thì true)
# 3. Viết hàm để xác định xem người chơi đã thắng hay chưa (check các khả năng thắng và hàng, cột, 2 đường chéo)
# 4. Viết một hàng để show bảng qua các lượt chơi nhiều lần
# 5. Viết hàm để bắt đầu trò chơi:
# *   Chọn random lượt đầu tiên của người chơi
# *   Viết một vòng lặp vô tận ngắt khi trò chơi kết thúc (thắng hoặc hòa).
#    - Hiển thị bảng để người dùng chọn vị trí cho nước đi tiếp theo.
#    - Yêu cầu người chơi nhập số hàng và cột.
#    - Cập nhật vị trí với dấu hiệu (X hoặc O) người chơi tương ứng.
#    - Kiểm tra xem người chơi hiện tại có thắng trò chơi hay không.
#    - Nếu người chơi hiện tại đã thắng trò chơi, sau đó in thông báo chiến thắng và phá vỡ vòng lặp vô tận.
#    - Tiếp theo, kiểm tra xem bảng đã được lấp đầy hay chưa.
#    - Nếu bảng được lấp đầy, sau đó in thông báo hoà và phá vỡ vòng lặp vô hạn.
# * Cuối cùng hiển thị cho người dùng chế độ xem cuối cùng của bảng.

# %% [markdown]
# # Phần 3: Code
# Nếu ở phần giải thuật bạn chưa rõ lắm thì không có gì đáng phải lo cả vì khi code thì bạn sẽ được hiểu rõ hoàn toàn.

# %%
import random


class TicTacToe:

    def __init__(self):
        self.board = []

    def create_board(self):
        for i in range(3):
            row = []
            for j in range(3):
                row.append('-')
            self.board.append(row)

    def get_random_first_player(self):
        return random.randint(0, 1)

    def fix_spot(self, row, col, player):
        self.board[row][col] = player

    def is_player_win(self, player):
        win = None

        n = len(self.board)

        # checking rows
        for i in range(n):
            win = True
            for j in range(n):
                if self.board[i][j] != player:
                    win = False
                    break
            if win:
                return win

        # checking columns
        for i in range(n):
            win = True
            for j in range(n):
                if self.board[j][i] != player:
                    win = False
                    break
            if win:
                return win

        # checking diagonals
        win = True
        for i in range(n):
            if self.board[i][i] != player:
                win = False
                break
        if win:
            return win

        win = True
        for i in range(n):
            if self.board[i][n - 1 - i] != player:
                win = False
                break
        if win:
            return win
        return False

        for row in self.board:
            for item in row:
                if item == '-':
                    return False
        return True

    def is_board_filled(self):
        for row in self.board:
            for item in row:
                if item == '-':
                    return False
        return True

    def swap_player_turn(self, player):
        return 'X' if player == 'O' else 'O'

    def show_board(self):
        for row in self.board:
            for item in row:
                print(item, end=" ")
            print()

    def start(self):
        self.create_board()

        player = 'X' if self.get_random_first_player() == 1 else 'O'
        while True:
            print(f"Player {player} turn")

            self.show_board()

            # taking user input
            row, col = list(
                map(int, input("Enter row and column numbers to fix spot: ").split()))
            print()

            # fixing the spot
            self.fix_spot(row - 1, col - 1, player)

            # checking whether current player is won or not
            if self.is_player_win(player):
                print(f"Player {player} wins the game!")
                break

            # checking whether the game is draw or not
            if self.is_board_filled():
                print("Match Draw!")
                break

            # swapping the turn
            player = self.swap_player_turn(player)

        # showing the final view of board
        print()
        self.show_board()


# starting the game
tic_tac_toe = TicTacToe()
tic_tac_toe.start()

# %%
# Sample Output
$ python tic_tac_toe.py 
Player X turn
- - -
- - -
- - -
Enter row and column numbers to fix spot: 1 1

Player O turn
X - -
- - -
- - -
Enter row and column numbers to fix spot: 2 1

Player X turn
X - -
O - -
- - -
Enter row and column numbers to fix spot: 1 2

Player O turn
X X -
O - -
- - -
Enter row and column numbers to fix spot: 1 3

Player X turn
X X O
O - -
- - -
Enter row and column numbers to fix spot: 2 2

Player O turn
X X O
O X -
- - -
Enter row and column numbers to fix spot: 3 3

Player X turn
X X O        
O X -        
- - O
Enter row and column numbers to fix spot: 3 2

Player X wins the game!

X X O
O X -
- X O

# %% [markdown]
# # Những điểm đáng lưu tâm để hiểu hơn về code
# * Bọn mình đã sử dụng class để lưu tất cả các phương thức ở một nơi để có thể dễ dàng tái sử dụng.
# * Bọn mình xác định các chức năng khác nhau cho từng tính năng ngay cả khi đó là một nhiệm vụ nhỏ. Nó giúp duy trì mã một cách dễ dàng.
# * Hai cách tiếp cận trên giúp bọn mình chỉnh sửa ứng dụng dễ dàng nếu bọn mình muốn cập nhật trò chơi.
#
# Các đã tạo một trò chơi hoàn toàn từ đầu. Nó không phải là một trong những trò chơi trực quan mà chúng ta chơi hàng ngày nhhưng nó giúp bạn viết logic và clear code. Bạn hoàn toàn có thể tự tạo trò chơi của mình theo những nguyên tắc ở trên.

# %% [markdown]
# Nguồn: [How to Create a Tic-Tac-Toe Game in Python?](https://geekflare.com/tic-tac-toe-python-code/)
