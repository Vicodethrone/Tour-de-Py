# %% [markdown]
# <a href="https://colab.research.google.com/github/Vicodethrone/Tour-de-Py/blob/main/Day_8_K%C3%A9o_b%C3%BAa_bao_nh%E1%BA%ADp_t%E1%BB%AB_b%C3%A0n_ph%C3%ADm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kéo Búa Bao (Rock - Paper - Scissors)
# Đây là trò chơi hai người mà hai người sẽ cùng nhau đưa ra các lựa chọn kéo, búa, hoặc bao. Búa sẽ thắng kéo, Kéo thắng bao, và bao thắng búa.
#
# Một phiên bản khác của trò chơi này là Rock-Paper-Scissors-Lizard-Spock khi có thêm hai vũ khí "the lizard" - (hình mà ngón cái, ngón trỏ và ngón giữa, ngón áp út và ngón út tạo thành một bàn tay 3 ngón) và Spock (là tên nhân vật trong loạt film "Star Trek")
#
# ![image.png](data:image/png;base64,...)
#
# [Nguồn ảnh](http://www.blackberryvietnam.net/threads/native-game-rock-paper-scissors-lizard-spock-bua-dao-keo.5944/)

# %% [markdown]
# [Demo game](https://www.askpython.com/wp-content/uploads/2020/06/rps-1.mp4)

# %% [markdown]
# ---

# %% [markdown]
# # Game menu
# Để giúp người chơi lựa chọn chơi hai phiên bản truyền thống và mới thì ta làm menu với giao diện như sau
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Tạo Data structure
# Có hai cấu trúc dữ liệu cần thiết cho hoạt động chính của trò chơi

# %%
# The mapping between moves and numbers
game_map = {0:"rock", 1:"paper", 2:"scissors", 3:"lizard", 4:"Spock"}
 
# Win-lose matrix for traditional game
rps_table = [[-1, 1, 0], [1, -1, 2], [0, 2, -1]]
 
# Win-lose matrix for new version of the game
rpsls_table = [[-1, 1, 0, 0, 4],[1, -1, 2, 3, 1], [0, 2, -1, 2, 4], [0, 3, 2, -1, 3], [4, 1, 4, 3, -1]]

# %% [markdown]
# # Lập bản đồ chuyển động trò chơi
# Chúng ta cần một loại ánh xạ nhất định giữa các nước đi và các con số có thể có, để xác định người chiến thắng và người thua cuộc.

# %% [markdown]
# # Ma trận thắng thua
#
# Cách đơn giản nhất để kiểm tra người chiến thắng trong trò oẳn tù tì bằng Python là tham khảo ô tương ứng với đầu vào của mỗi người chơi. Dưới đây là ma trận cho trò chơi truyền thống:
#
# ![image.png](data:image/png;base64,...)
#
# Các giá trị không âm của ma trận biểu thị phần thắng của các đầu vào tương ứng. Để rõ hơn các bạn hãy xem qua ví dụ:
#
# Giả sử, người chơi 1 chọn Kéo (chỉ số = 2) và người chơi 2 chọn Giấy (chỉ số = 1). Các ô (2, 1) và (1, 2) trong ma trận, biểu thị sự trùng khớp giữa Kéo và Giấy. Các ô này chứa chỉ số của Kéo vì Kéo cắt Giấy.
#
# Các ô chứa '-1' biểu thị một trò chơi hòa.
#
# Dưới đây là ma trận của new version:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Các cấu trúc dữ liệu được giải thích ở trên tổng hợp logic trò chơi hoàn chỉnh cần thiết để tạo ra trò chơi Rock-Paper-Scissors. Hai điều vẫn còn là quản lý đầu vào của người chơi và nước đi của máy tính.
#
#
# ---

# %% [markdown]
# # Thiết lập vòng lặp
#
# Một trong những phần quan trọng nhất của kéo bú bao là Vòng lặp. Trong bối cảnh của trò chơi này, vòng lặp trò chơi có nhiệm vụ duy trì một chuỗi các trận đấu giữa những người chơi.

# %%
# The GAME LOOP
while True:
 
    # The Game Menu
    print()
    print("Let's Play!!!")
    print("Which version of Rock-Paper-Scissors?")
    print("Enter 1 to play Rock-Paper-Scissors")
    print("Enter 2 to play Rock-Paper-Scissors-Lizard-Spock")
    print("Enter 3 to quit")
    print()
 
    # Try block to handle the player choice 
    try:
        choice = int(input("Enter your choice = "))
    except ValueError:
        clear()
        print("Wrong Choice")   
        continue
 
    # Play the traditional version of the game
    if choice == 1:
        rps()
 
    # Play the new version of the game
    elif choice == 2:
        rpsls()
 
    # Quit the GAME LOOP    
    elif choice == 3:
        break
 
    # Other wrong input
    else:
        clear()
        print("Wrong choice. Read instructions carefully.")

# %% [markdown]
# Các hàm 'rps ()' và 'rpsls ()' có một vòng lặp trò chơi bên trong để xử lý một loạt các trò chơi thuộc các phiên bản tương ứng của chúng.
#
# Hàm ‘clear () 'chịu trách nhiệm xóa terminal, để ngăn chặn output quá mức cần thiết
#
# ---

# %% [markdown]
# # Cung câp hướng dẫn cho người chơi
#
# Trước khi mong đợi một người chơi thực hiện một bước đi, nhiệm vụ của lập trình viên là cung cấp một bộ hướng dẫn cho người chơi. Chúng ta cần tạo hai chức năng riêng biệt để đưa ra hướng dẫn cho cả hai loại trò chơi.

# %%
# Set of instructions for Rock-Paper-Scissors
def rps_instructions():
 
    print()
    print("Instructions for Rock-Paper-Scissors : ")
    print()
    print("Rock crushes Scissors")
    print("Scissors cuts Paper")
    print("Paper covers Rock")
    print()
 
# Set of instructions for Rock-Paper-Scissors-Lizard-Spock
def rpsls_instructions():
 
    print()
    print("Instructions for Rock-Paper-Scissors-Lizard-Spock : ")
    print()
    print("Scissors cuts Paper")
    print("Paper covers Rock")
    print("Rock crushes Lizard")
    print("Lizard poisons Spock")
    print("Spock smashes Scissors")
    print("Scissors decapitates Lizard")
    print("Lizard eats Paper")
    print("Paper disproves Spock")
    print("Spock vaporizes Rock")
    print("Rock crushes Scissors")
    print()

# %% [markdown]
# Sau khi hiển thị xong hướng dẫn thì bắt đầu yêu cầu người chơi chọn nước đi tương ứng với phiên bản chơi đấy
#
# ---

# %% [markdown]
# # Xử lý đầu vào người chơi
#
# Vì trò chơi là giữa người và máy tính nên phải thực hiện một động tác duy nhất cho mỗi lượt chơi

# %% [markdown]
# # Menu đầu vào
#
# Chúng ta cần cung cấp cho người chơi cảm giác kiểm soát trò chơi. Chúng ta có thể làm như vậy bằng cách cung cấp các tùy chọn “yêu cầu trợ giúp”, “các động thái khả thi” và “thoát khỏi trò chơi”. Menu đầu vào sau đây sẽ giải quyết vấn đề này:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Chuyển động người chơi
#
# Trọng tâm chính của việc xử lý đầu vào trình phát là chuyển đổi đầu vào chuỗi thành ánh xạ số. Đối với trò chơi oẳn tù tì truyền thống bằng Python, chúng tôi chấp nhận các động thái đầu vào sau, sử dụng câu lệnh điều kiện để kiểm tra

# %%
# Player Input
inp = input("Enter your move : ")
 
if inp.lower() == "help":
    clear()
    rps_instructions()
    continue
elif inp.lower() == "exit":
    clear()
    break  
elif inp.lower() == "rock":
    player_move = 0
elif inp.lower() == "paper":
    player_move = 1    
elif inp.lower() == "scissors":
    player_move = 2
else:
    clear()
    print("Wrong Input!!")
    rps_instructions()  
    continue

# %% [markdown]
# ---

# %% [markdown]
# # Chuyển động của máy tính
#
# Để quản lý việc di chuyển máy tính không thiên vị, chúng ta cần nhờ đến sự trợ giúp của thư viện 'random' của Python. Chúng ta chọn một động thái ngẫu nhiên từ các tùy chọn có thể.

# %%
# Get the computer move randomly
comp_move = random.randint(0, 2) # lựa chọn range để chuyện động random cho máy
 
# Print the computer move
print("Computer chooses ", game_map[comp_move].upper())

# %% [markdown]
# ---

# %% [markdown]
# # Phân chia thắng thua
#
# Sử dụng ma trận thắng thua, chúng ta có thể dễ dàng chọn ra người chiến thắng.

# %%
# Find the winner of the match
winner = rps_table[player_move][comp_move]
 
# Declare the winner 
if winner == player_move:
    print(name, "WINS!!!")
elif winner == comp_move:
    print("COMPUTER WINS!!!")
else:
    print("TIE GAME")
print()
time.sleep(2) # tạm dừng thực thi câu lệnh trong 2s
clear()

# %% [markdown]
# ---

# %%
# Code hoàn chỉnh
import random
import os
import time


def clear():
    os.system('cls' if os.name == 'nt' else 'clear')
    return ("   ")


# Set of instructions for Rock-Paper-Scissors
def rps_instructions():
    print()
    print("Instructions for Rock-Paper-Scissors : ")
    print()
    print("Rock crushes Scissors")
    print("Scissors cuts Paper")
    print("Paper covers Rock")
    print()


# Set of instructions for Rock-Paper-Scissors-Lizard-Spock
def rpsls_instructions():
    print()
    print("Instructions for Rock-Paper-Scissors-Lizard-Spock : ")
    print()
    print("Scissors cuts Paper")
    print("Paper covers Rock")
    print("Rock crushes Lizard")
    print("Lizard poisons Spock")
    print("Spock smashes Scissors")
    print("Scissors decapitates Lizard")
    print("Lizard eats Paper")
    print("Paper disproves Spock")
    print("Spock vaporizes Rock")
    print("Rock crushes Scissors")
    print()


def rps():
    global rps_table
    global game_map
    global name

    # Game Loop for each game of Rock-Paper-Scissors
    while True:

        print("--------------------------------------")
        print("\t\tMenu")
        print("--------------------------------------")
        print("Enter \"help\" for instructions")
        print("Enter \"Rock\",\"Paper\",\"Scissors\" to play")
        print("Enter \"exit\" to quit")
        print("--------------------------------------")

        print()

        # Player Input
        inp = input("Enter your move : ")

        if inp.lower() == "help":
            clear()
            rps_instructions()
            continue
        elif inp.lower() == "exit":
            clear()
            break
        elif inp.lower() == "rock":
            player_move = 0
        elif inp.lower() == "paper":
            player_move = 1
        elif inp.lower() == "scissors":
            player_move = 2
        else:
            clear()
            print("Wrong Input!!")
            rps_instructions()
            continue

        print("Computer making a move....")

        print()
        time.sleep(2)

        # Get the computer move randomly
        comp_move = random.randint(0, 2)

        # Print the computer move
        print("Computer chooses ", game_map[comp_move].upper())

        # Find the winner of the match
        winner = rps_table[player_move][comp_move]

        # Declare the winner
        if winner == player_move:
            print(name, "WINS!!!")
        elif winner == comp_move:
            print("COMPUTER WINS!!!")
        else:
            print("TIE GAME")

        print()
        time.sleep(2)
        clear()


def rpsls():
    global rpsls_table
    global game_map
    global name

    # Game Loop for each game of Rock-Paper-Scissors-Lizard-Spock
    while True:
        print("--------------------------------------")
        print("\t\tMenu")
        print("--------------------------------------")
        print("Enter \"help\" for instructions")
        print("Enter \"Rock\",\"Paper\",\"Scissors\",\"Lizard\",\"Spock\" to play")
        print("Enter \"exit\" to quit")
        print("--------------------------------------")

        print()

        # Player Input
        inp = input("Enter your move : ")

        if inp.lower() == "help":
            clear()
            rpsls_instructions()
            continue
        elif inp.lower() == "exit":
            clear()
            break
        elif inp.lower() == "rock":
            player_move = 0
        elif inp.lower() == "paper":
            player_move = 1
        elif inp.lower() == "scissors":
            player_move = 2
        elif inp.lower() == "lizard":
            player_move = 3
        elif inp.lower() == "spock":
            player_move = 4
        else:
            clear()
            print("Wrong Input!!")
            rps_instructions()
            continue

        print("Computer making a move....")

        comp_move = random.randint(0, 4)
        print()
        time.sleep(2)

        print("Computer chooses ", game_map[comp_move].upper())

        winner = rpsls_table[player_move][comp_move]
        print()
        if winner == player_move:
            print(name, "WINS!!!")
        elif winner == comp_move:
            print("COMPUTER WINS!!!")
        else:
            print("TIE GAME")
        print()
        time.sleep(2)
        clear()


# The main function
if __name__ == '__main__':

    # The mapping between moves and numbers
    game_map = {0: "rock", 1: "paper", 2: "scissors", 3: "lizard", 4: "Spock"}

    # Win-lose matrix for traditional game
    rps_table = [[-1, 1, 0], [1, -1, 2], [0, 2, -1]]

    # Win-lose matrix for new version of the game
    rpsls_table = [[-1, 1, 0, 0, 4], [1, -1, 2, 3, 1], [0, 2, -1, 2, 4], [0, 3, 2, -1, 3], [4, 1, 4, 3, -1]]

    name = input("Enter your name: ")

    # The GAME LOOP
    while True:

        # The Game Menu
        print()
        print("Let's Play!!!")
        print("Which version of Rock-Paper-Scissors?")
        print("Enter 1 to play Rock-Paper-Scissors")
        print("Enter 2 to play Rock-Paper-Scissors-Lizard-Spock")
        print("Enter 3 to quit")
        print()

        # Try block to handle the player choice
        try:
            choice = int(input("Enter your choice = "))
        except ValueError:
            clear()
            print("Wrong Choice")
            continue

        # Play the traditional version of the game
        if choice == 1:
            rps()

        # Play the new version of the game
        elif choice == 2:
            rpsls()

        # Quit the GAME LOOP
        elif choice == 3:
            break

        # Other wrong input
        else:
            clear()
            print("Wrong choice. Read instructions carefully.")

# %% [markdown]
# Nguồn: [askpython.com](https://www.askpython.com/python/examples/rock-paper-scissors-in-python)
